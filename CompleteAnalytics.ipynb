# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-56899ffd-6a83-40ba-82e8-fcc73dfae084" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56899ffd-6a83-40ba-82e8-fcc73dfae084">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dede6664-23d0-4946-b843-4a086122acdb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dede6664-23d0-4946-b843-4a086122acdb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
bdf = pd.read_csv('Behaviour Anomaly.csv')
mdf = pd.read_csv('Mark Anomaly.csv')

# %%
bdf
# Out:
#      CandidateID  quick_completion  hardware_changes  external_pings  \
# 0        4041001                 1                 1               0
# 1        4041002                 1                 1               1
# 2        4041003                 0                 1               1
# 3        4041004                 0                 0               1
# 4        4041005                 0                 1               1
# ..           ...               ...               ...             ...
# 435      4041436                 1                 1               0
# 436      4041437                 0                 1               1
# 437      4041438                 1                 1               0
# 438      4041439                 0                 1               0
# 439      4041440                 1                 1               0
#
#      exam_delay  late_start  fast_answer  num_questions_answered  mal
# ...

# %%
mdf
# Out:
#      CandidateID    M1    M2    M3    M4    M5  Final  Predicted  Difference  \
# 0        4041001  71.0  72.0  78.0  75.0  77.0   75.0       82.0        -7.0
# 1        4041002  88.0  84.0  82.0  89.0  82.0   80.0       92.0       -12.0
# 2        4041003  57.0  55.0  57.0  53.0  53.0   65.0       58.0         7.0
# 3        4041004  63.0  61.0  60.0  66.0  67.0   61.0       71.0       -10.0
# 4        4041005  67.0  60.0  60.0  61.0  63.0   83.0       68.0        15.0
# ..           ...   ...   ...   ...   ...   ...    ...        ...         ...
# 435      4041436  55.0  57.0  54.0  57.0  51.0   86.0       58.0        28.0
# 436      4041437  71.0  77.0  75.0  74.0  76.0   76.0       81.0        -5.0
# 437      4041438  59.0  58.0  57.0  55.0  58.0   67.4       62.0         5.4
# 438      4041439  64.0  60.0  60.0  64.0  60.0   87.0       67.0        20.0
# 439      4041440  54.0  50.0  51.0  52.0  55.0   89.0       58.0        31.0
#
# ...

# %%
malpractice_candidates = []
for (index1, row1), (index2, row2) in zip(bdf.iterrows(), mdf.iterrows()):
    if row1['mal'] == 1:
      if row2['Outlier'] == 1:
        print(row1['CandidateID'])
# Out:
# 4041025
# 4041215
# 4041320
# 4041369
# 4041440
